# %% [markdown]
# Code-snippet for active code development, will reload the library if any changes.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from project_template import paths_and_constants, vis
_P = paths_and_constants.Paths()
_C = paths_and_constants.Constants()
vis.set_visualization_style()
